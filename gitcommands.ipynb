# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !git config --global user.name "aalocked"
# !git config --global user.email "aalokchhetri16@gmail.com"
# !git config --global user.password "DmcKg5lmd"

# %%
token = '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'
username = 'aalocked'
repo = 'Text2MCQ'

# %%
# !pwd
# Out:
# /content

# %%
# %ls
# Out:
# gdrive/  sample_data/

# %%
# %cd gdrive
# Out:
# /content/gdrive

# %%
# %ls
# Out:
# MyDrive/

# %%
# %cd MyDrive
# Out:
# /content/gdrive/MyDrive

# %%
# %ls
# Out:
# 'Aalok Chhetri NAAMII.gdoc'
# 'Aalok Chhetri Resume.gdoc'
# 'Aalok Chhetri resume.pdf'
#  annoted_data_xmls/
# 'antenna aalok.pdf'
# 'bert_base-augmented-batch_size=128-lr=2e-5-max_gloss=6'/
# 'bert_base-augmented-batch_size=128-lr=2e-5-max_gloss=6.zip'
#  BERT-WSD-master/
# 'Book 03-19-2021 09.50 (1).pdf'
# 'Book 03-19-2021 09.50.pdf'
# 'Book 03-20-2021 13.11.pdf'
# 'Bootstrap HTML5 Responsive Templates'/
#  Buffer.pdf
# 'Build and Deploy Node.js Apps with Microsoft Azure - Participant Slides (V2).gdoc'
#  BulkResizePohtole/
#  Canon/
#  catalyst.pdf
#  cgg.pdf
# 'Chapter 2.gdoc'
#  Classroom/
# 'Colab Notebooks'/
# 'Copy of firstname_application_for_gajabaar2021.gdoc'
# 'Copy of Math Subject for Elementary - 4th Grade: Operations and Algebraic Thinking by Slidesgo.gslides'
# 'Copy of Minimalist Business Slides by Slidesgo.gslides'
# 'Copy of Minimalist Marketing Plan | by Slidesgo (1).gslides'
# 'Copy of Minimalist Marketing Plan | by Slidesgo (2).gslides'
# ...

# %%
# %cd Colab Notebooks
# Out:
# /content/gdrive/MyDrive/Colab Notebooks

# %%
# %ls
# Out:
#  bayesianpothole.ipynb             Text2MCQ/
# 'Diabetes Prediction.ipynb'        traintestsplit.ipynb
# 'Dog vs Cats.ipynb'                Untitled0.ipynb
# 'House Price Prediction.ipynb'     Untitled1.ipynb
# 'Movie Recommender System.ipynb'   Untitled2.ipynb
# 'Rock vs Mine Prediction.ipynb'    Untitled3.ipynb

# %%
# %cd Text2MCQ
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/Text2MCQ

# %%
# %ls
# Out:
# gitcommands.ipynb  Text2MCQ.ipynb

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/gdrive/MyDrive/Colab Notebooks/Text2MCQ/.git/

# %%
# !git remote add origin https://aalocked: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@github.com/aalocked/Text2MCQ.git
